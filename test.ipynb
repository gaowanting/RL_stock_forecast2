# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv('./common/new_data_file/data.csv')

# %%
df[["trade_date"]] = df[["trade_date"]].astype(str)

# %%
df[["trade_date"]].dtypes
# Out:
# trade_date    object
# dtype: object

# %%
df["date"] = df.trade_date.apply(lambda x: datetime.strptime(x[:4] + '-' + x[4:6] + '-' + x[6:], "%Y-%m-%d"))

# %%
landmark_series = df[df['landmark'].isin(["v","^"])]

# %%
landmark_series.reset_index()
# Out:
#      index  Unnamed: 0        date        tic     open     high      low  \
# 0        3           3  2010-05-06  300077.SZ  33.0336  35.6904  32.5306
# 1        6           6  2010-05-11  300077.SZ  31.6139  31.6158  28.9377
# 2        7           7  2010-05-12  300077.SZ  29.1319  30.8798  28.4832
# 3       11          11  2010-05-18  300077.SZ  28.1589  28.2968  25.6360
# 4       12          12  2010-05-19  300077.SZ  26.6265  29.8932  26.4576
# ..     ...         ...         ...        ...      ...      ...      ...
# 602   2123        2123  2019-05-23  300077.SZ   9.1200   9.1200   8.6100
# 603   2124        2124  2019-05-24  300077.SZ   8.2000   8.3900   7.7800
# 604   2127        2127  2019-05-29  300077.SZ   7.9400   8.3300   7.9000
# 605   2131        2131  2019-06-04  300077.SZ   7.7300   7.8900   7.5400
# 606   2132        2132  2019-06-05  300077.SZ   7.7100   7.9200   7.5900
#
#        close     volume   day       kdjk       kdjd       kdjj       rsi_6  \
# ...

# %%
landmark_series.landmark[90:110]
# Out:
# 329    ^
# 331    v
# 334    ^
# 336    v
# 337    ^
# 343    v
# 344    ^
# 345    v
# 348    ^
# 354    v
# 364    ^
# 366    v
# 368    ^
# 369    v
# 373    ^
# 377    v
# 381    ^
# 382    v
# 383    ^
# 385    v
# Name: landmark, dtype: object

# %%
current_index = 12

# %%
y_previous, previous_signal = landmark_series.loc[landmark_series.index == (current_index-1),['close','landmark']]

# %%
y_previous, a = landmark_series.loc[landmark_series.index == (current_index-1),('close','landmark')]
y_previous
# Out:
# 'close'

# %%
previous_signal
# Out:
# 'landmark'
